# %% [markdown]
# # Implementation of Polygon

# %%
from classes.Point import Point
from classes.Polygon import Polygon

# %%
poly_points = [ Point(2,2), Point(10,4), Point(12,12), Point(3,10) ]
poly_1 = Polygon(poly_points)
poly_1.draw()

print("Polygon is convex" if poly_1.is_convex() else "Polygon is concave")
# Out:
# 2,2 10,4 12,12 True
# 10,4 12,12 3,10 True
# 12,12 3,10 2,2 True
# Polygon is convex

# %%
poly_points = [ Point(2,12), Point(10,4), Point(12,12), Point(5,5), Point(3,10) ]
poly_1 = Polygon(poly_points)
poly_1.draw()

print("Polygon is convex" if poly_1.is_convex() else "Polygon is concave")
# Out:
# 5,5 10,4 12,12 True
# 10,4 12,12 2,12 True
# 12,12 2,12 3,10 True
# 2,12 3,10 5,5 False
# Polygon is concave
